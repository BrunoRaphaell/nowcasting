# %% [markdown]
# # Dados Banco central

# %%
import pandas as pd

# %%
import requests
r = requests.get("https://api.bcb.gov.br/dados/serie/v2/​listar​?formato=json&indicador=433")
print(r.json())
# Out:
# {'error': 'endpoint not found!'}

# %%
df = pd.read_parquet(r"C:\Users\Matheus\Desktop\CEDS_workspace\TCC CEDS\nowcasting\data\raw\selic_acumulada_mes.parquet")
df.head()
# Out:
#             selic_acumulada_mes
# date
# 2011-01-01                 0.86
# 2011-02-01                 0.84
# 2011-03-01                 0.92
# 2011-04-01                 0.84
# 2011-05-01                 0.99

# %%
df.tail()
# Out:
#             selic_acumulada_mes
# date
# 2025-10-01                 1.28
# 2025-11-01                 1.05
# 2025-12-01                 1.22
# 2026-01-01                 1.16
# 2026-02-01                 0.55

# %%
# Inadimplência - Taxa de inadimplência do crédito para pessoas físicas
df_inad = pd.read_csv("https://api.bcb.gov.br/dados/serie/bcdata.sgs.21084/dados?formato=csv", sep = ';')
df_inad.head()
# Out:
#          data valor
# 0  01/03/2011  4,62
# 1  01/04/2011  4,67
# 2  01/05/2011  4,82
# 3  01/06/2011  4,79
# 4  01/07/2011  4,90

# %%
# atividade econômica - Atividade econômica mensal - IBC-Br - com ajuste sazonal
df_atv_eco = pd.read_csv("https://api.bcb.gov.br/dados/serie/bcdata.sgs.24364/dados?formato=csv", sep = ';')
df_atv_eco.head()
# Out:
#          data     valor
# 0  01/01/2003  70,54523
# 1  01/02/2003  71,73128
# 2  01/03/2003  71,35367
# 3  01/04/2003  70,86296
# 4  01/05/2003  70,16612

# %%
# taxa selic
df_selic = pd.read_csv("https://api.bcb.gov.br/dados/serie/bcdata.sgs.4189/dados?formato=csv", sep = ';')
df_selic.head()
# Out:
#          data  valor
# 0  01/08/1986  35,55
# 1  01/09/1986  39,39
# 2  01/10/1986  23,65
# 3  01/11/1986  34,32
# 4  01/12/1986  83,98

# %%
df_selic.tail()
# Out:
#            data  valor
# 470  01/10/2025  14,90
# 471  01/11/2025  14,90
# 472  01/12/2025  14,90
# 473  01/01/2026  14,90
# 474  01/02/2026  14,90

# %%
df_ibge = pd.read_csv("C:\\Users\\Matheus\\Desktop\\CEDS_workspace\\TCC CEDS\\nowcasting\\data\\raw\\tabela4095.csv", sep = ',', encoding = 'utf-8')
df_ibge.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df_ibge = pd.read_csv("C:\\Users\\Matheus\\Desktop\\CEDS_workspace\\TCC CEDS\\nowcasting\\data\\raw\\tabela4095.csv", sep = ',', encoding = 'utf-8')
#       2 df_ibge.head()
#
# ...

# %%
import sidrapy

# %%
#https://apisidra.ibge.gov.br/values/t/4095/n1/all/v/all/p/all/c1568/all/d/v4087%201,v4089%201,v4091%201,v4093%201,v4095%201,v4096%201,v4097%201,v4098%201,v4099%201,v4100%201,v4101%201,v4102%201,v4103%201,v4104%201,v4105%201,v4106%201,v4107%201,v4108%201,v4109%201,v4110%201,v4111%201,v4112%201,v4113%201,v4724%201,v4726%201,v4774%201,v12466%201,v12467%201
df_ibge = sidrapy.get_table(table_code="4095", territorial_level="1", ibge_territorial_code="all", variable="all", period="all")

# %%
#https://apisidra.ibge.gov.br/values/t/8880/n1/all/v/7170/p/all/c11046/56734/d/v7170%205
df_ibge = sidrapy.get_table(table_code="8880", territorial_level="1", ibge_territorial_code="all", variable="7170", period="all")

# %%
df_ibge.head()
# Out:
#                            NC                 NN                          MC  \
# 0  Nível Territorial (Código)  Nível Territorial  Unidade de Medida (Código)
# 1                           1             Brasil                          30
# 2                           1             Brasil                          30
# 3                           1             Brasil                          30
# 4                           1             Brasil                          30
#
#                   MN      V              D1C     D1N           D2C  \
# 0  Unidade de Medida  Valor  Brasil (Código)  Brasil  Mês (Código)
# 1      Número-índice     ..                1  Brasil        200001
# 2      Número-índice     ..                1  Brasil        200002
# 3      Número-índice     ..                1  Brasil        200003
# 4      Número-índice     ..                1  Brasil        200004
#
#               D2N                D3C  \
# 0             Mês  Variável (Código)
# ...

# %%
import sidrapy

# %%
# !pip install bcb
# Out:
# ERROR: Could not find a version that satisfies the requirement bcb (from versions: none)
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for bcb

# %%
sidrapy.get_table()
