# %% [markdown]
# # 03 — Results
#
# Load walk-forward evaluation results and discuss findings.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import Image, display

pd.options.display.float_format = "{:.4f}".format

# %% [markdown]
# ## Model Comparison

# %%
metrics = pd.read_csv("../results/model_comparison.csv")
metrics

# %%
display(Image("../results/model_comparison.png"))

# %% [markdown]
# ## Predictions Over Time

# %%
preds = pd.read_csv("../results/predictions.csv", index_col="date", parse_dates=True)
preds.tail(10)

# %%
display(Image("../results/actual_vs_predicted.png"))

# %% [markdown]
# ## Feature Importance

# %%
import os
if os.path.exists("../results/xgboost_importance.png"):
    display(Image("../results/xgboost_importance.png"))
if os.path.exists("../results/elasticnet_coefficients.png"):
    display(Image("../results/elasticnet_coefficients.png"))
